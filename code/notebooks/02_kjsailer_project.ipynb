# %% [markdown]
# # Project: Levels of Football
#
# Kaleb Sailer
#
# This is the cleaning and data frame merging file.

# %% [markdown]
# ### Packages

# %%
import pandas as pd

# %% [markdown]
# ## High School Data Cleaning

# %%
hs_stats_df = pd.read_csv('hs_stats_raw.csv')

# %%
hs_stats_df.dtypes
# Out:
# team_name     object
# W              int64
# L              int64
# ppg          float64
# ppg_a        float64
# ppg_diff     float64
# pass_yds       int64
# pass_tds       int64
# rush_yds       int64
# rush_tds       int64
# off_tds        int64
# dtype: object

# %%
# data engineering
hs_stats_df['pass_ypg'] = round(hs_stats_df['pass_yds']/(hs_stats_df['W'] + hs_stats_df['L']), 1)

hs_stats_df['rush_ypg'] = round(hs_stats_df['rush_yds']/(hs_stats_df['W'] + hs_stats_df['L']), 1)

hs_stats_df['win_pct'] = round(hs_stats_df['W']/(hs_stats_df['W'] + hs_stats_df['L']), 2)

hs_stats_df['ypg'] = round(hs_stats_df['pass_ypg'] + hs_stats_df['rush_ypg'], 1)

hs_stats_df['state'] = 'IA'

# team level
hs_stats_df['team_level'] = 'HS'
hs_stats_df['team_level'] = hs_stats_df['team_level'].astype('category')

# %%
hs_stats_df.head()
# Out:
#            team_name   W  L   ppg  ppg_a  ppg_diff  pass_yds  pass_tds  \
# 0     Southeast Polk  13  0  39.5   17.5      22.0      2653        29
# 1   Dowling Catholic   9  2  32.4   11.7      20.6      1402        11
# 2             Ankeny   9  4  25.6   24.0       1.6      2314        20
# 3   Waukee Northwest   7  3  34.9   17.6      17.3      1491        16
# 4  Ankeny Centennial   7  5  33.8   14.2      19.7      1887        21
#
#    rush_yds  rush_tds  off_tds  pass_ypg  rush_ypg  win_pct    ypg state  \
# 0      2175        38       67     204.1     167.3     1.00  371.4    IA
# 1      1988        31       42     127.5     180.7     0.82  308.2    IA
# 2      2222        24       44     178.0     170.9     0.69  348.9    IA
# 3      1794        27       43     149.1     179.4     0.70  328.5    IA
# 4      2114        31       52     157.2     176.2     0.58  333.4    IA
#
#   team_level
# 0         HS
# 1         HS
# 2         HS
# 3         HS
# 4         HS

# %% [markdown]
# ## College Data

# %%
cfb_df = pd.read_csv('cfb23.csv')

# %%
display(cfb_df.head())
# Out:
#    Unnamed: 0 Off Rank               Team Games Win-Loss Off Plays Off Yards  \
# 0           0        1          LSU (SEC)    13     10-3       841      7065
# 1           1        2    Oregon (Pac-12)    14     12-2       951      7440
# 2           2        3  Oklahoma (Big 12)    13     10-3       974      6591
# 3           3        4     Liberty (CUSA)    14     13-1       973      6988
# 4           4        5      Georgia (SEC)    14     13-1       958      6951
#
#   Off Yards/Play Off TDs Off Yards per Game  ...  \
# 0           8.40      78              543.5  ...
# 1           7.82      82              531.4  ...
# 2           6.77      66              507.0  ...
# 3           7.18      71              499.1  ...
# 4           7.26      69              496.5  ...
#
#   Average Time of Possession per Game Turnover Rank Fumbles Recovered  \
# 0                               28:51            23                 4
# 1                               31:03             9                 6
# 2                               29:04            23                 6
# 3                               33:04            21                 4
# 4                               33:28            43                 3
#
#   Opponents Intercepted Turnovers Gain Fumbles Lost Interceptions Thrown_y  \
# 0                    10             14            3                      5
# 1                    12             18            2                      5
# 2                    20             26           11                      9
# 3                    21             25           12                      6
# 4                    14             17            7                      7
#
#   Turnovers Lost Turnover Margin Avg Turnover Margin per Game
# 0              8               6                         0.46
# 1              7              11                         0.79
# 2             20               6                         0.46
# 3             18               7                         0.50
# 4             14               3                         0.21
#
# [5 rows x 152 columns]

# %%
# dropping columns by specifying what columns to keep
cfb_df = cfb_df[['Team', 'Win-Loss', 'Off Yards per Game', 'Rush Yds', 'Pass Yards',
    'Points Per Game', 'Avg Points per Game Allowed', 'Rushing TD', 'Pass Touchdowns', 'Off TDs']]

display(cfb_df.head())
# Out:
#                 Team Win-Loss Off Yards per Game Rush Yds Pass Yards  \
# 0          LSU (SEC)     10-3              543.5     2659       4406
# 1    Oregon (Pac-12)     12-2              531.4     2583       4857
# 2  Oklahoma (Big 12)     10-3              507.0     2368       4223
# 3     Liberty (CUSA)     13-1              499.1     4106       2882
# 4      Georgia (SEC)     13-1              496.5     2677       4274
#
#   Points Per Game Avg Points per Game Allowed Rushing TD Pass Touchdowns  \
# 0            45.5                        28.0         34              44
# 1            44.2                        16.5         33              49
# 2            41.7                        23.5         32              34
# 3            38.3                        23.9         39              32
# 4            40.1                        15.6         40              29
#
#   Off TDs
# 0      78
# 1      82
# 2      66
# 3      71
# 4      69

# %%
# drop the reclassifying rows
cfb_df = cfb_df[cfb_df['Win-Loss'] != 'Reclassifying']

# modifying data types - converting to float for calculations later
cfb_df[['Rush Yds', 'Pass Yards', 'Points Per Game', 'Avg Points per Game Allowed']] = cfb_df[['Rush Yds', 'Pass Yards', 'Points Per Game', 'Avg Points per Game Allowed']].astype('float')

# %%
# modfiying columns and changing column names

# Splitting 'Team' into 'team_name' and 'conference'
cfb_df['team_name'] = cfb_df['Team'].str.extract(r'^(.*?)(?=\s\()')[0].str.strip()
cfb_df['conference'] = cfb_df['Team'].str.extract(r'\(([^()]+)\)$')[0].str.strip()

# Splitting Win-Loss into 'Wins' and 'Losses'
cfb_df['W'] = cfb_df['Win-Loss'].str.split('-', expand=True)[0].astype(int)
cfb_df['L'] = cfb_df['Win-Loss'].str.split('-', expand=True)[1].astype(int)

# Calculating Rushing Yards per Game and Passing Yards per Game
cfb_df['rush_ypg'] = round(cfb_df['Rush Yds'] / (cfb_df['W'] + cfb_df['L']), 1)
cfb_df['pass_ypg'] = round(cfb_df['Pass Yards'] / (cfb_df['W'] + cfb_df['L']), 1)

# Calculating point differential and win percentage
cfb_df['ppg_diff'] = round(cfb_df['Points Per Game'] - cfb_df['Avg Points per Game Allowed'], 1)
cfb_df['win_pct'] = round(cfb_df['W'] / (cfb_df['W'] + cfb_df['L']), 2)

cfb_df = cfb_df.rename(columns={
    'Points Per Game': 'ppg',
    'Avg Points per Game Allowed': 'ppg_a',
    'Rushing TD': 'rush_tds',
    'Pass Touchdowns': 'pass_tds',
    'Off TDs': 'off_tds',
    'Off Yards per Game': 'ypg'
})

# %%
# dropping unneeded columns and reordering columns
cfb_df = cfb_df[[
    'team_name', 'conference', 'W', 'L', 'ppg', 'ppg_a', 'ppg_diff', 
    'pass_tds', 'rush_tds', 'off_tds', 'pass_ypg', 'rush_ypg', 
    'win_pct', 'ypg'
]]

# %%
# adding level
cfb_df['team_level'] = 'College'

# correcting data types
cfb_df[['conference', 'team_level']] = cfb_df[['conference', 'team_level']].astype('category')
cfb_df[['rush_tds', 'pass_tds', 'off_tds']] = cfb_df[['rush_tds', 'pass_tds', 'off_tds']].astype('int')
cfb_df['ypg'] = cfb_df['ypg'].astype('float')

cfb_df.dtypes
# Out:
# team_name       object
# conference    category
# W                int32
# L                int32
# ppg            float64
# ppg_a          float64
# ppg_diff       float64
# pass_tds         int32
# rush_tds         int32
# off_tds          int32
# pass_ypg       float64
# rush_ypg       float64
# win_pct        float64
# ypg            float64
# team_level    category
# dtype: object

# %% [markdown]
# ## NFL Data

# %%
nfl_df = pd.read_csv('nfl_df_raw.csv')

# %%
# data engineering/adding more columns
nfl_df['win_pct'] = round(nfl_df['W']/(nfl_df['W'] + nfl_df['L']), 2)

nfl_df['conference'] = ['AFC'] * 16 + ['NFC'] * 16

nfl_df['ypg'] = round(nfl_df['pass_ypg'] + nfl_df['rush_ypg'], 1)

# Dictionary mapping each team to its state abbreviation
team_state_abbr = {
    'Buffalo Bills': 'NY', 
    'Miami Dolphins': 'FL', 
    'New York Jets': 'NJ', 
    'New England Patriots': 'MA', 
    'Baltimore Ravens': 'MD', 
    'Cleveland Browns': 'OH', 
    'Pittsburgh Steelers': 'PA', 
    'Cincinnati Bengals': 'OH', 
    'Houston Texans': 'TX', 
    'Jacksonville Jaguars': 'FL', 
    'Indianapolis Colts': 'IN', 
    'Tennessee Titans': 'TN', 
    'Kansas City Chiefs': 'MO', 
    'Las Vegas Raiders': 'NV', 
    'Denver Broncos': 'CO', 
    'Los Angeles Chargers': 'CA', 
    'Dallas Cowboys': 'TX', 
    'Philadelphia Eagles': 'PA', 
    'New York Giants': 'NJ', 
    'Washington Commanders': 'MD', 
    'Detroit Lions': 'MI', 
    'Green Bay Packers': 'WI', 
    'Minnesota Vikings': 'MN', 
    'Chicago Bears': 'IL', 
    'Tampa Bay Buccaneers': 'FL', 
    'New Orleans Saints': 'LA', 
    'Atlanta Falcons': 'GA', 
    'Carolina Panthers': 'NC', 
    'San Francisco 49ers': 'CA', 
    'Los Angeles Rams': 'CA', 
    'Seattle Seahawks': 'WA', 
    'Arizona Cardinals': 'AZ'
}

# Loop through the index and assign state abbreviation based on team name
for i in nfl_df.index:
    team_name = nfl_df.loc[i, 'team_name']
    if team_name in team_state_abbr:
        nfl_df.loc[i, 'state'] = team_state_abbr[team_name]

nfl_df['team_level'] = 'NFL'

# %%
# making conference and state categorical
nfl_df[['conference', 'state', 'team_level']] = nfl_df[['conference', 'state', 'team_level']].astype('category')

# %%
display(nfl_df)
# Out:
#                 team_name   W   L   ppg  ppg_a  ppg_diff  pass_ypg  rush_ypg  \
# 0           Buffalo Bills  11   6  26.5   18.3       8.2     244.4     130.1
# 1          Miami Dolphins  11   6  29.2   23.0       6.2     265.5     135.8
# 2           New York Jets   7  10  15.8   20.9      -5.1     171.7      96.9
# 3    New England Patriots   4  13  13.9   21.5      -7.6     180.5      95.7
# 4        Baltimore Ravens  13   4  28.4   16.5      11.9     213.8     156.5
# 5        Cleveland Browns  11   6  23.3   21.3       2.0     217.2     118.6
# 6     Pittsburgh Steelers  10   7  17.9   19.1      -1.2     186.1     118.2
# 7      Cincinnati Bengals   9   8  21.5   22.6      -1.1     229.1      89.8
# 8          Houston Texans  10   7  22.2   20.8       1.4     245.5      96.9
# 9    Jacksonville Jaguars   9   8  22.2   21.8       0.4     242.7      96.8
# 10     Indianapolis Colts   9   8  23.3   24.4      -1.1     215.6     121.1
# 11       Tennessee Titans   6  11  17.9   21.6      -3.7     180.4     108.6
# 12     Kansas City Chiefs  11   6  21.8   17.3       4.5     246.4     104.9
# 13      Las Vegas Raiders   8   9  19.5   19.5       0.0     198.8      90.7
# 14         Denver Broncos   8   9  21.0   24.3      -3.3     191.9     106.5
# 15   Los Angeles Chargers   5  12  20.4   23.4      -3.0     232.8      96.6
# 16         Dallas Cowboys  12   5  29.9   18.5      11.4     258.6     112.9
# 17    Philadelphia Eagles  11   6  25.5   25.2       0.3     225.5     128.8
# 18        New York Giants   6  11  15.6   23.9      -8.3     169.8     110.2
# 19  Washington Commanders   4  13  19.4   30.5     -11.1     219.1      93.6
# 20          Detroit Lions  12   5  27.1   23.2       3.9     258.9     135.9
# 21      Green Bay Packers   9   8  22.5   20.6       1.9     233.4     112.1
# 22      Minnesota Vikings   7  10  20.2   21.3      -1.1     256.4      91.4
# 23          Chicago Bears   7  10  21.2   22.3      -1.1     182.1     141.1
# 24   Tampa Bay Buccaneers   9   8  20.5   19.1       1.4     224.2      88.8
# 25     New Orleans Saints   9   8  23.6   19.2       4.4     234.7     102.5
# 26        Atlanta Falcons   7  10  18.9   21.9      -3.0     207.3     127.0
# 27      Carolina Panthers   2  15  13.9   24.5     -10.6     161.2     104.1
# 28    San Francisco 49ers  12   5  28.9   17.5      11.4     257.9     140.5
# 29       Los Angeles Rams  10   7  23.8   22.2       1.6     239.0     120.3
# 30       Seattle Seahawks   9   8  21.4   23.6      -2.2     230.0      92.9
# 31      Arizona Cardinals   4  13  19.4   26.8      -7.4     184.9     139.1
#
#     off_tds  rush_tds  pass_tds  win_pct conference    ypg state team_level
# 0        51        22        29     0.65        AFC  374.5    NY        NFL
# 1        57        27        30     0.65        AFC  401.3    FL        NFL
# 2        18         7        11     0.41        AFC  268.6    NJ        NFL
# 3        25         9        16     0.24        AFC  276.2    MA        NFL
# 4        53        26        27     0.76        AFC  370.3    MD        NFL
# 5        39        15        24     0.65        AFC  335.8    OH        NFL
# 6        29        16        13     0.59        AFC  304.3    PA        NFL
# 7        39        12        27     0.53        AFC  318.9    OH        NFL
# 8        37        10        27     0.59        AFC  342.4    TX        NFL
# 9        39        17        22     0.53        AFC  339.5    FL        NFL
# 10       37        19        18     0.53        AFC  336.7    IN        NFL
# 11       30        16        14     0.35        AFC  289.0    TN        NFL
# 12       37         9        28     0.65        AFC  351.3    MO        NFL
# 13       31        11        20     0.47        AFC  289.5    NV        NFL
# 14       36         8        28     0.47        AFC  298.4    CO        NFL
# 15       35        11        24     0.29        AFC  329.4    CA        NFL
# 16       50        14        36     0.71        NFC  371.5    TX        NFL
# 17       46        22        24     0.65        NFC  354.3    PA        NFL
# 18       25        10        15     0.35        NFC  280.0    NJ        NFL
# 19       38        14        24     0.24        NFC  312.7    MD        NFL
# 20       57        27        30     0.71        NFC  394.8    MI        NFL
# 21       42        10        32     0.53        NFC  345.5    WI        NFL
# 22       37         7        30     0.41        NFC  347.8    MN        NFL
# 23       35        16        19     0.41        NFC  323.2    IL        NFL
# 24       36         8        28     0.53        NFC  313.0    FL        NFL
# 25       41        13        28     0.53        NFC  337.2    LA        NFL
# 26       31        14        17     0.41        NFC  334.3    GA        NFL
# 27       20         7        13     0.12        NFC  265.3    NC        NFL
# 28       60        27        33     0.71        NFC  398.4    CA        NFL
# 29       44        18        26     0.59        NFC  359.3    CA        NFL
# 30       34        11        23     0.53        NFC  322.9    WA        NFL
# 31       35        17        18     0.24        NFC  324.0    AZ        NFL

# %% [markdown]
# ## Merging of the DataFrames

# %%
# HS and college 
hs_cfb_df = pd.concat([hs_stats_df, cfb_df], ignore_index=True)

# writing to .csv
hs_cfb_df.to_csv('hs_cfb_df.csv', encoding='utf-8')

display(hs_cfb_df)
# Out:
#              team_name   W  L   ppg  ppg_a  ppg_diff  pass_yds  pass_tds  \
# 0       Southeast Polk  13  0  39.5   17.5      22.0    2653.0        29
# 1     Dowling Catholic   9  2  32.4   11.7      20.6    1402.0        11
# 2               Ankeny   9  4  25.6   24.0       1.6    2314.0        20
# 3     Waukee Northwest   7  3  34.9   17.6      17.3    1491.0        16
# 4    Ankeny Centennial   7  5  33.8   14.2      19.7    1887.0        21
# ..                 ...  .. ..   ...    ...       ...       ...       ...
# 164      Eastern Mich.   6  7  19.5   26.7      -7.2       NaN        10
# 165               Iowa  10  4  15.4   14.8       0.6       NaN         9
# 166      James Madison  11  2  34.1   19.5      14.6       NaN        36
# 167   Jacksonville St.   9  4  30.2   21.2       9.0       NaN        12
# 168        Sam Houston   3  9  20.0   26.2      -6.2       NaN        15
#
#      rush_yds  rush_tds  off_tds  pass_ypg  rush_ypg  win_pct    ypg state  \
# 0      2175.0        38       67     204.1     167.3     1.00  371.4    IA
# 1      1988.0        31       42     127.5     180.7     0.82  308.2    IA
# 2      2222.0        24       44     178.0     170.9     0.69  348.9    IA
# 3      1794.0        27       43     149.1     179.4     0.70  328.5    IA
# 4      2114.0        31       52     157.2     176.2     0.58  333.4    IA
# ..        ...       ...      ...       ...       ...      ...    ...   ...
# 164       NaN        18       28     152.0     110.8     0.46  262.8   NaN
# 165       NaN        11       20     118.6     115.9     0.71  234.6   NaN
# 166       NaN        17       53     284.8     134.2     0.85  418.9   NaN
# 167       NaN        35       47     171.0     236.7     0.69  407.7   NaN
# 168       NaN        13       28     222.5      88.9     0.25  311.4   NaN
#
#     team_level conference
# 0           HS        NaN
# 1           HS        NaN
# 2           HS        NaN
# 3           HS        NaN
# 4           HS        NaN
# ..         ...        ...
# 164    College        MAC
# 165    College    Big Ten
# 166    College   Sun Belt
# 167    College       CUSA
# 168    College       CUSA
#
# [169 rows x 18 columns]

# %%
# college and NFL
cfb_nfl_df = pd.concat([cfb_df, nfl_df], ignore_index=True)

# writing to .csv
cfb_nfl_df.to_csv('cfb_nfl_df.csv', encoding='utf-8')

display(cfb_nfl_df)
# Out:
#                team_name conference   W   L   ppg  ppg_a  ppg_diff  pass_tds  \
# 0                    LSU        SEC  10   3  45.5   28.0      17.5        44
# 1                 Oregon     Pac-12  12   2  44.2   16.5      27.7        49
# 2               Oklahoma     Big 12  10   3  41.7   23.5      18.2        34
# 3                Liberty       CUSA  13   1  38.3   23.9      14.4        32
# 4                Georgia        SEC  13   1  40.1   15.6      24.5        29
# ..                   ...        ...  ..  ..   ...    ...       ...       ...
# 160    Carolina Panthers        NFC   2  15  13.9   24.5     -10.6        13
# 161  San Francisco 49ers        NFC  12   5  28.9   17.5      11.4        33
# 162     Los Angeles Rams        NFC  10   7  23.8   22.2       1.6        26
# 163     Seattle Seahawks        NFC   9   8  21.4   23.6      -2.2        23
# 164    Arizona Cardinals        NFC   4  13  19.4   26.8      -7.4        18
#
#      rush_tds  off_tds  pass_ypg  rush_ypg  win_pct    ypg team_level state
# 0          34       78     338.9     204.5     0.77  543.5    College   NaN
# 1          33       82     346.9     184.5     0.86  531.4    College   NaN
# 2          32       66     324.8     182.2     0.77  507.0    College   NaN
# 3          39       71     205.9     293.3     0.93  499.1    College   NaN
# 4          40       69     305.3     191.2     0.93  496.5    College   NaN
# ..        ...      ...       ...       ...      ...    ...        ...   ...
# 160         7       20     161.2     104.1     0.12  265.3        NFL    NC
# 161        27       60     257.9     140.5     0.71  398.4        NFL    CA
# 162        18       44     239.0     120.3     0.59  359.3        NFL    CA
# 163        11       34     230.0      92.9     0.53  322.9        NFL    WA
# 164        17       35     184.9     139.1     0.24  324.0        NFL    AZ
#
# [165 rows x 16 columns]

# %%
# HS and NFL
hs_nfl_df = pd.concat([hs_stats_df, nfl_df], ignore_index=True)

# writing to .csv
hs_nfl_df.to_csv('hs_nfl_df.csv', encoding='utf-8')

display(hs_nfl_df)
# Out:
#               team_name   W   L   ppg  ppg_a  ppg_diff  pass_yds  pass_tds  \
# 0        Southeast Polk  13   0  39.5   17.5      22.0    2653.0        29
# 1      Dowling Catholic   9   2  32.4   11.7      20.6    1402.0        11
# 2                Ankeny   9   4  25.6   24.0       1.6    2314.0        20
# 3      Waukee Northwest   7   3  34.9   17.6      17.3    1491.0        16
# 4     Ankeny Centennial   7   5  33.8   14.2      19.7    1887.0        21
# ..                  ...  ..  ..   ...    ...       ...       ...       ...
# 63    Carolina Panthers   2  15  13.9   24.5     -10.6       NaN        13
# 64  San Francisco 49ers  12   5  28.9   17.5      11.4       NaN        33
# 65     Los Angeles Rams  10   7  23.8   22.2       1.6       NaN        26
# 66     Seattle Seahawks   9   8  21.4   23.6      -2.2       NaN        23
# 67    Arizona Cardinals   4  13  19.4   26.8      -7.4       NaN        18
#
#     rush_yds  rush_tds  off_tds  pass_ypg  rush_ypg  win_pct    ypg state  \
# 0     2175.0        38       67     204.1     167.3     1.00  371.4    IA
# 1     1988.0        31       42     127.5     180.7     0.82  308.2    IA
# 2     2222.0        24       44     178.0     170.9     0.69  348.9    IA
# 3     1794.0        27       43     149.1     179.4     0.70  328.5    IA
# 4     2114.0        31       52     157.2     176.2     0.58  333.4    IA
# ..       ...       ...      ...       ...       ...      ...    ...   ...
# 63       NaN         7       20     161.2     104.1     0.12  265.3    NC
# 64       NaN        27       60     257.9     140.5     0.71  398.4    CA
# 65       NaN        18       44     239.0     120.3     0.59  359.3    CA
# 66       NaN        11       34     230.0      92.9     0.53  322.9    WA
# 67       NaN        17       35     184.9     139.1     0.24  324.0    AZ
#
#    team_level conference
# 0          HS        NaN
# 1          HS        NaN
# 2          HS        NaN
# 3          HS        NaN
# 4          HS        NaN
# ..        ...        ...
# 63        NFL        NFC
# 64        NFL        NFC
# 65        NFL        NFC
# 66        NFL        NFC
# 67        NFL        NFC
#
# [68 rows x 18 columns]

# %%
# all three
all_fb_df = pd.concat([hs_cfb_df, nfl_df], ignore_index=True)

# writing to .csv
all_fb_df.to_csv('all_fb.csv', encoding='utf-8')

display(all_fb_df)
# Out:
#                team_name   W   L   ppg  ppg_a  ppg_diff  pass_yds  pass_tds  \
# 0         Southeast Polk  13   0  39.5   17.5      22.0    2653.0        29
# 1       Dowling Catholic   9   2  32.4   11.7      20.6    1402.0        11
# 2                 Ankeny   9   4  25.6   24.0       1.6    2314.0        20
# 3       Waukee Northwest   7   3  34.9   17.6      17.3    1491.0        16
# 4      Ankeny Centennial   7   5  33.8   14.2      19.7    1887.0        21
# ..                   ...  ..  ..   ...    ...       ...       ...       ...
# 196    Carolina Panthers   2  15  13.9   24.5     -10.6       NaN        13
# 197  San Francisco 49ers  12   5  28.9   17.5      11.4       NaN        33
# 198     Los Angeles Rams  10   7  23.8   22.2       1.6       NaN        26
# 199     Seattle Seahawks   9   8  21.4   23.6      -2.2       NaN        23
# 200    Arizona Cardinals   4  13  19.4   26.8      -7.4       NaN        18
#
#      rush_yds  rush_tds  off_tds  pass_ypg  rush_ypg  win_pct    ypg state  \
# 0      2175.0        38       67     204.1     167.3     1.00  371.4    IA
# 1      1988.0        31       42     127.5     180.7     0.82  308.2    IA
# 2      2222.0        24       44     178.0     170.9     0.69  348.9    IA
# 3      1794.0        27       43     149.1     179.4     0.70  328.5    IA
# 4      2114.0        31       52     157.2     176.2     0.58  333.4    IA
# ..        ...       ...      ...       ...       ...      ...    ...   ...
# 196       NaN         7       20     161.2     104.1     0.12  265.3    NC
# 197       NaN        27       60     257.9     140.5     0.71  398.4    CA
# 198       NaN        18       44     239.0     120.3     0.59  359.3    CA
# 199       NaN        11       34     230.0      92.9     0.53  322.9    WA
# 200       NaN        17       35     184.9     139.1     0.24  324.0    AZ
#
#     team_level conference
# 0           HS        NaN
# 1           HS        NaN
# 2           HS        NaN
# 3           HS        NaN
# 4           HS        NaN
# ..         ...        ...
# 196        NFL        NFC
# 197        NFL        NFC
# 198        NFL        NFC
# 199        NFL        NFC
# 200        NFL        NFC
#
# [201 rows x 18 columns]
